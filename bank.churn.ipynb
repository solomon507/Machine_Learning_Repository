# %%
#importing necessary libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:\Intellipaat\lms assignments\datasets\customer_churn.csv")
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
customer_5 = data['tenure']
customer_5
# Out:
# 0        1
# 1       34
# 2        2
# 3       45
# 4        2
#         ..
# 7038    24
# 7039    72
# 7040    11
# 7041     4
# 7042    66
# Name: tenure, Length: 7043, dtype: int64

# %%
customer_15 = data.iloc[:,14]
customer_15
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingMovies, Length: 7043, dtype: object

# %%
senior_male_electronic = data[(data['gender'] == 'Male')& (data['PaymentMethod'] == 'Electronic check')]
senior_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 14    5129-JLPIS   Male              0      No         No      25
# 20    8779-QRDMV   Male              1      No         No       1
# 26    6467-CHFZW   Male              0     Yes        Yes      47
# 27    8665-UTDHZ   Male              0     Yes        Yes       1
# 36    6047-YHPVI   Male              0      No         No       5
# ...          ...    ...            ...     ...        ...     ...
# 7014  9053-EJUNL   Male              0      No         No      41
# 7020  9837-FWLCH   Male              0     Yes        Yes      12
# 7021  1699-HPSBG   Male              0      No         No      12
# 7022  7203-OYKCT   Male              0      No         No      72
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 14            Yes                No     Fiber optic                  Yes  ...
# ...

# %%
customer_total_tenur = data[(data['tenure']> 70) | (data['MonthlyCharges']>100)]
customer_total_tenur
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic                   No  ...
# ...

# %%
two_mail_yes = data[(data['Contract'] == 'Two year') & (data['PaymentMethod'] =='Mailed check') & (data['Churn']== 'Yes')]
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
customer_333 = data.sample(n=333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4681  9965-YOKZB    Male              1      No         No       9
# 668   3859-CVCET  Female              0      No         No       4
# 1554  9313-QOLTZ    Male              0      No         No      26
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# 320   5020-ZSTTY  Female              1      No         No      54
# ...          ...     ...            ...     ...        ...     ...
# 6833  9129-UXERG  Female              1      No         No      18
# 1569  0799-DDIHE  Female              0     Yes        Yes      15
# 1822  4911-BANWH  Female              0      No        Yes      31
# 6250  3705-RHRFR  Female              0     Yes         No      69
# 5339  3370-GQEAL    Male              0     Yes        Yes      30
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4681          Yes           Yes     Fiber optic                   No  ...
# ...

# %%
data['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
count_of_categories = data['InternetService'].value_counts()
count_of_categories
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
plt.bar(count_of_categories.index,count_of_categories,color = 'orange')
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count of Categories')
plt.title('Distribution of Internet Service')
plt.show()

# %%
plt.hist(data['tenure'],bins=30,color='green')
plt.title('Distribution of tenure')
plt.show()

# %%
plt.scatter(data['tenure'],data['MonthlyCharges'], color = 'brown')
plt.xlabel('Tenure of customer')
plt.ylabel('Monthly Charges of customer')
plt.title('Tenure vs Monthly Charges')
plt.show()

# %%
sns.boxplot(x='Contract',y= 'tenure',data = data)
plt.show()

# %%
# Linear regression model
x = data[['tenure']]
y = data['MonthlyCharges']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import root_mean_squared_error, accuracy_score,confusion_matrix

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.3,random_state=0)

# %%
linear = LinearRegression()
linear
# Out:
# LinearRegression()

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear.predict(x_test)
y_pred
# Out:
# array([60.95089608, 72.98096699, 59.1903979 , ..., 75.62171426,
#        70.63363608, 65.6455579 ])

# %%
rmse = root_mean_squared_error(y_test,y_pred)
rmse
# Out:
# 29.394584027273893

# %%
error = y_test-y_pred
error
# Out:
# 2200    -2.750896
# 4627    43.619033
# 3225    12.759602
# 2828   -35.219402
# 3768     6.236115
#           ...
# 4448    35.521524
# 1231     3.155688
# 3304    34.328286
# 4805   -46.083636
# 5843    15.954442
# Name: MonthlyCharges, Length: 2113, dtype: float64

# %%
np.sqrt(rmse)
# Out:
# 5.4216772337786665

# %%
# Logistic Regression

# %%
x = data[['MonthlyCharges']]
y = data['Churn']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.35,random_state=0)

# %%
logistic = LogisticRegression()
logistic
# Out:
# LogisticRegression()

# %%
logistic.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logistic.predict(x_test)
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
confusion = confusion_matrix(y_test,y_pred)
print(confusion)
# Out:
# [[1815    0]
#  [ 651    0]]

# %%
acc = accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.7360097323600974

# %%
x_train = data[['tenure','MonthlyCharges']]
y_train = data['Churn']

# %%
x_train,x_test,y_train,y_test = train_test_split(x_train,y_train, test_size = 0.2,random_state=0)

# %%
logistic.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logistic.predict(x_test)
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7735982966643009

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[934, 107],
#        [212, 156]], dtype=int64)

# %%
# Decision Tree

# %%
X = data[['tenure']]
Y = data['Churn']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size = 0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state=0)
model
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'Yes'], dtype=object)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[965,  76],
#        [281,  87]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7466288147622427

# %%
#Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
A = data[['MonthlyCharges','tenure']]
B = data['Churn']

# %%
x_train,x_test,y_train,y_test = train_test_split(A,B ,test_size= 0.3, random_state=1)

# %%
model = RandomForestClassifier()
model
# Out:
# RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array(['Yes', 'Yes', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1361,  224],
#        [ 277,  251]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7628963558920966
